# %%
import nd2
import xml.etree.ElementTree as ET

# %%
# Input files
nd2_microscope_images = '20250220_Galvano-Full-Plate.nd2'
positions_file = 'multipoints.xml'

# %%
# Read nd2 file 
with nd2.ND2File(nd2_microscope_images) as f:
    ome = f.ome_metadata()
    xml = ome.to_xml()

# Write the nd2 XML string to a file
with open("microscope_image_data.xml", "w", encoding="utf-8") as xml_file:
    xml_file.write(xml)

# %% [markdown]
# ND2: Finding the image name, x-position, and y-position in the microscope images file

# %%
# Parse the nd2 XML file
tree_images = ET.parse('microscope_image_data.xml')
root_images = tree_images.getroot()

# Define the namespace dictionary
ns = {'ome': 'http://www.openmicroscopy.org/Schemas/OME/2016-06'}

# List to hold results
planes = []

# Iterate over each Image element
for image in root_images.findall('ome:Image', ns):
    image_name = image.get('Name')
    # Find the first Plane element within the Pixels element
    plane = image.find('.//ome:Plane', ns)
    if plane is not None:
        posX = float(plane.get('PositionX'))
        posY = float(plane.get('PositionY'))
        planes.append({
            'image_name': image_name,
            'posX': posX,
            'posY': posY
        })

# %%
# Print the results
for item in planes:
    print(item)
# Out:
# {'image_name': '20250220_Galvano-Full-Plate (Series 0)', 'posX': 42151.1, 'posY': -22766.5}
# {'image_name': '20250220_Galvano-Full-Plate (Series 1)', 'posX': 41225.0, 'posY': -22449.5}
# {'image_name': '20250220_Galvano-Full-Plate (Series 2)', 'posX': 41365.7, 'posY': -21952.4}
# {'image_name': '20250220_Galvano-Full-Plate (Series 3)', 'posX': 40293.8, 'posY': -13686.6}
# {'image_name': '20250220_Galvano-Full-Plate (Series 4)', 'posX': 40339.1, 'posY': -11346.8}
# {'image_name': '20250220_Galvano-Full-Plate (Series 5)', 'posX': 39000.4, 'posY': -11719.0}
# {'image_name': '20250220_Galvano-Full-Plate (Series 6)', 'posX': 41159.7, 'posY': -4477.3}
# {'image_name': '20250220_Galvano-Full-Plate (Series 7)', 'posX': 41577.1, 'posY': -2551.5}
# {'image_name': '20250220_Galvano-Full-Plate (Series 8)', 'posX': 38947.2, 'posY': -2794.1}
# {'image_name': '20250220_Galvano-Full-Plate (Series 9)', 'posX': 40389.6, 'posY': 4829.5}
# {'image_name': '20250220_Galvano-Full-Plate (Series 10)', 'posX': 41157.4, 'posY': 4672.5}
# {'image_name': '20250220_Galvano-Full-Plate (Series 11)', 'posX': 42354.0, 'posY': 5574.1}
# {'image_name': '20250220_Galvano-Full-Plate (Series 12)', 'posX': 39484.2, 'posY': 14312.0}
# {'image_name': '20250220_Galvano-Full-Plate (Series 13)', 'posX': 39096.7, 'posY': 15147.0}
# {'image_name': '20250220_Galvano-Full-Plate (Series 14)', 'posX': 40666.7, 'posY': 15376.3}
# {'image_name': '20250220_Galvano-Full-Plate (Series 15)', 'posX': 32581.8, 'posY': -22678.7}
# {'image_name': '20250220_Galvano-Full-Plate (Series 16)', 'posX': 33403.2, 'posY': -22337.6}
# {'image_name': '20250220_Galvano-Full-Plate (Series 17)', 'posX': 31548.5, 'posY': -20729.3}
# {'image_name': '20250220_Galvano-Full-Plate (Series 18)', 'posX': 32033.5, 'posY': -13499.9}
# {'image_name': '20250220_Galvano-Full-Plate (Series 19)', 'posX': 31556.1, 'posY': -11634.6}
# {'image_name': '20250220_Galvano-Full-Plate (Series 20)', 'posX': 30136.0, 'posY': -11804.9}
# {'image_name': '20250220_Galvano-Full-Plate (Series 21)', 'posX': 31347.0, 'posY': -5105.3}
# {'image_name': '20250220_Galvano-Full-Plate (Series 22)', 'posX': 30362.1, 'posY': -4664.2}
# {'image_name': '20250220_Galvano-Full-Plate (Series 23)', 'posX': 29575.7, 'posY': -3901.6}
# {'image_name': '20250220_Galvano-Full-Plate (Series 24)', 'posX': 30928.2, 'posY': 4715.1}
# {'image_name': '20250220_Galvano-Full-Plate (Series 25)', 'posX': 30088.6, 'posY': 4821.7}
# {'image_name': '20250220_Galvano-Full-Plate (Series 26)', 'posX': 29123.0, 'posY': 4621.3}
# {'image_name': '20250220_Galvano-Full-Plate (Series 27)', 'posX': 30464.0, 'posY': 13968.2}
# {'image_name': '20250220_Galvano-Full-Plate (Series 28)', 'posX': 29709.5, 'posY': 14107.6}
# {'image_name': '20250220_Galvano-Full-Plate (Series 29)', 'posX': 29709.5, 'posY': 14107.6}
# {'image_name': '20250220_Galvano-Full-Plate (Series 30)', 'posX': 13763.4, 'posY': -22886.1}
# {'image_name': '20250220_Galvano-Full-Plate (Series 31)', 'posX': 12820.4, 'posY': -23428.4}
# {'image_name': '20250220_Galvano-Full-Plate (Series 32)', 'posX': 12503.5, 'posY': -24139.2}
# {'image_name': '20250220_Galvano-Full-Plate (Series 33)', 'posX': 13517.5, 'posY': -13365.4}
# {'image_name': '20250220_Galvano-Full-Plate (Series 34)', 'posX': 12345.6, 'posY': -13724.4}
# {'image_name': '20250220_Galvano-Full-Plate (Series 35)', 'posX': 12180.5, 'posY': -14617.9}
# {'image_name': '20250220_Galvano-Full-Plate (Series 36)', 'posX': 13032.5, 'posY': -4327.6}
# {'image_name': '20250220_Galvano-Full-Plate (Series 37)', 'posX': 13199.9, 'posY': -5149.9}
# {'image_name': '20250220_Galvano-Full-Plate (Series 38)', 'posX': 13088.1, 'posY': -6125.0}
# {'image_name': '20250220_Galvano-Full-Plate (Series 39)', 'posX': 12668.8, 'posY': 5181.1}
# {'image_name': '20250220_Galvano-Full-Plate (Series 40)', 'posX': 12408.7, 'posY': 5672.5}
# {'image_name': '20250220_Galvano-Full-Plate (Series 41)', 'posX': 11988.4, 'posY': 5957.4}
# {'image_name': '20250220_Galvano-Full-Plate (Series 42)', 'posX': 11929.1, 'posY': 14119.3}
# {'image_name': '20250220_Galvano-Full-Plate (Series 43)', 'posX': 11944.6, 'posY': 14779.1}
# {'image_name': '20250220_Galvano-Full-Plate (Series 44)', 'posX': 12919.3, 'posY': 15338.7}
# {'image_name': '20250220_Galvano-Full-Plate (Series 45)', 'posX': 4779.7, 'posY': -22452.2}
# {'image_name': '20250220_Galvano-Full-Plate (Series 46)', 'posX': 4090.5, 'posY': -22234.0}
# {'image_name': '20250220_Galvano-Full-Plate (Series 47)', 'posX': 2637.3, 'posY': -21545.6}
# {'image_name': '20250220_Galvano-Full-Plate (Series 48)', 'posX': 3688.3, 'posY': -13200.4}
# {'image_name': '20250220_Galvano-Full-Plate (Series 49)', 'posX': 2850.2, 'posY': -13335.7}
# {'image_name': '20250220_Galvano-Full-Plate (Series 50)', 'posX': 2020.9, 'posY': -14022.7}
# {'image_name': '20250220_Galvano-Full-Plate (Series 51)', 'posX': 3741.6, 'posY': -4124.5}
# {'image_name': '20250220_Galvano-Full-Plate (Series 52)', 'posX': 3120.3, 'posY': -3728.9}
# {'image_name': '20250220_Galvano-Full-Plate (Series 53)', 'posX': 3773.6, 'posY': -2813.7}
# {'image_name': '20250220_Galvano-Full-Plate (Series 54)', 'posX': 2993.6, 'posY': 5036.8}
# {'image_name': '20250220_Galvano-Full-Plate (Series 55)', 'posX': 2399.8, 'posY': 4896.9}
# {'image_name': '20250220_Galvano-Full-Plate (Series 56)', 'posX': 2122.8, 'posY': 4113.4}
# {'image_name': '20250220_Galvano-Full-Plate (Series 57)', 'posX': 2662.0, 'posY': 14194.8}
# {'image_name': '20250220_Galvano-Full-Plate (Series 58)', 'posX': 3006.5, 'posY': 14718.9}
# {'image_name': '20250220_Galvano-Full-Plate (Series 59)', 'posX': 3980.1, 'posY': 15143.7}
# {'image_name': '20250220_Galvano-Full-Plate (Series 60)', 'posX': -13754.9, 'posY': -22301.1}
# {'image_name': '20250220_Galvano-Full-Plate (Series 61)', 'posX': -13600.4, 'posY': -21453.3}
# {'image_name': '20250220_Galvano-Full-Plate (Series 62)', 'posX': -13944.4, 'posY': -20608.4}
# {'image_name': '20250220_Galvano-Full-Plate (Series 63)', 'posX': -13560.3, 'posY': -13072.3}
# {'image_name': '20250220_Galvano-Full-Plate (Series 64)', 'posX': -12689.1, 'posY': -12526.2}
# {'image_name': '20250220_Galvano-Full-Plate (Series 65)', 'posX': -11995.5, 'posY': -12314.8}
# {'image_name': '20250220_Galvano-Full-Plate (Series 66)', 'posX': -15485.4, 'posY': -3244.9}
# {'image_name': '20250220_Galvano-Full-Plate (Series 67)', 'posX': -13823.9, 'posY': -2503.3}
# {'image_name': '20250220_Galvano-Full-Plate (Series 68)', 'posX': -12223.5, 'posY': -3363.9}
# {'image_name': '20250220_Galvano-Full-Plate (Series 69)', 'posX': -15560.5, 'posY': 5599.7}
# {'image_name': '20250220_Galvano-Full-Plate (Series 70)', 'posX': -14677.3, 'posY': 6209.0}
# {'image_name': '20250220_Galvano-Full-Plate (Series 71)', 'posX': -13958.8, 'posY': 6320.8}
# {'image_name': '20250220_Galvano-Full-Plate (Series 72)', 'posX': -14728.1, 'posY': 15214.4}
# {'image_name': '20250220_Galvano-Full-Plate (Series 73)', 'posX': -14010.5, 'posY': 15159.8}
# {'image_name': '20250220_Galvano-Full-Plate (Series 74)', 'posX': -12996.3, 'posY': 14334.6}
# {'image_name': '20250220_Galvano-Full-Plate (Series 75)', 'posX': -23238.5, 'posY': -22237.3}
# {'image_name': '20250220_Galvano-Full-Plate (Series 76)', 'posX': -23848.8, 'posY': -22238.8}
# {'image_name': '20250220_Galvano-Full-Plate (Series 77)', 'posX': -24327.6, 'posY': -21706.8}
# {'image_name': '20250220_Galvano-Full-Plate (Series 78)', 'posX': -24513.4, 'posY': -12552.0}
# {'image_name': '20250220_Galvano-Full-Plate (Series 79)', 'posX': -24710.3, 'posY': -13021.8}
# {'image_name': '20250220_Galvano-Full-Plate (Series 80)', 'posX': -24652.4, 'posY': -13598.2}
# {'image_name': '20250220_Galvano-Full-Plate (Series 81)', 'posX': -24689.4, 'posY': -4106.5}
# {'image_name': '20250220_Galvano-Full-Plate (Series 82)', 'posX': -24806.2, 'posY': -4685.8}
# {'image_name': '20250220_Galvano-Full-Plate (Series 83)', 'posX': -24480.7, 'posY': -5482.0}
# {'image_name': '20250220_Galvano-Full-Plate (Series 84)', 'posX': -24455.5, 'posY': 5136.7}
# {'image_name': '20250220_Galvano-Full-Plate (Series 85)', 'posX': -24353.9, 'posY': 4061.4}
# {'image_name': '20250220_Galvano-Full-Plate (Series 86)', 'posX': -24506.5, 'posY': 3036.6}
# {'image_name': '20250220_Galvano-Full-Plate (Series 87)', 'posX': -24757.6, 'posY': 13841.5}
# {'image_name': '20250220_Galvano-Full-Plate (Series 88)', 'posX': -24753.1, 'posY': 13161.9}
# {'image_name': '20250220_Galvano-Full-Plate (Series 89)', 'posX': -23513.8, 'posY': 12946.5}

# %% [markdown]
# Multipoint: Finding the positions name, x-position, and y-position in the multipoints file

# %%
# Parse multipoints XML file 
tree_positions = ET.parse(positions_file)
root_positions = tree_positions .getroot()

# Find the container of the point elements (named 'no_name')
no_name = root_positions.find('no_name')

# List to hold the results
points = []

# Iterate over all child elements (e.g., Point00000, Point00001, etc.)
for point in no_name:
    # Extract the 'value' attribute from the sub-elements: strName, dXPosition, dYPosition
    name_elem = point.find('strName')
    x_elem = point.find('dXPosition')
    y_elem = point.find('dYPosition')
    
    if name_elem is not None and x_elem is not None and y_elem is not None:
        strName = name_elem.get('value')
        dX = float(x_elem.get('value'))
        dY = float(y_elem.get('value'))
        points.append({
            'strName': strName,
            'dX': dX,
            'dY': dY
        })

# %%
# Print the results
for p in points:
    print(p)
# Out:
# {'strName': 'B2_1', 'dX': 42151.100000000006, 'dY': -22766.5}
# {'strName': 'B2_2', 'dX': 41225.0, 'dY': -22449.5}
# {'strName': 'B2_3', 'dX': 41365.700000000004, 'dY': -21952.4}
# {'strName': 'C2_1', 'dX': 40293.8, 'dY': -13686.6}
# {'strName': 'C2_2', 'dX': 40339.100000000006, 'dY': -11346.800000000001}
# {'strName': 'C2_3', 'dX': 39000.4, 'dY': -11719.0}
# {'strName': 'D2_1', 'dX': 41159.700000000004, 'dY': -4477.3}
# {'strName': 'D2_2', 'dX': 41577.100000000006, 'dY': -2551.5}
# {'strName': 'D2_3', 'dX': 38947.200000000004, 'dY': -2794.1000000000004}
# {'strName': 'E2_1', 'dX': 40389.600000000006, 'dY': 4829.5}
# {'strName': 'E2_2', 'dX': 41157.4, 'dY': 4672.5}
# {'strName': 'E2_3', 'dX': 42354.0, 'dY': 5574.1}
# {'strName': 'F2_1', 'dX': 39484.200000000004, 'dY': 14312.0}
# {'strName': 'F2_2', 'dX': 39096.700000000004, 'dY': 15147.0}
# {'strName': 'F2_3', 'dX': 40666.700000000004, 'dY': 15376.300000000001}
# {'strName': 'B3_1', 'dX': 32581.800000000003, 'dY': -22678.7}
# {'strName': 'B3_2', 'dX': 33403.200000000004, 'dY': -22337.600000000002}
# {'strName': 'B3_3', 'dX': 31548.5, 'dY': -20729.300000000003}
# {'strName': 'C3_1', 'dX': 32033.5, 'dY': -13499.900000000001}
# {'strName': 'C3_2', 'dX': 31556.100000000002, 'dY': -11634.6}
# {'strName': 'C3_3', 'dX': 30136.0, 'dY': -11804.900000000001}
# {'strName': 'D3_1', 'dX': 31347.0, 'dY': -5105.3}
# {'strName': 'D3_2', 'dX': 30362.100000000002, 'dY': -4664.2}
# {'strName': 'D3_3', 'dX': 29575.7, 'dY': -3901.6000000000004}
# {'strName': 'E3_1', 'dX': 30928.2, 'dY': 4715.1}
# {'strName': 'E3_2', 'dX': 30088.600000000002, 'dY': 4821.7}
# {'strName': 'E3_3', 'dX': 29123.0, 'dY': 4621.3}
# {'strName': 'F3_1', 'dX': 30464.0, 'dY': 13968.2}
# {'strName': 'F3_2', 'dX': 29709.5, 'dY': 14107.6}
# {'strName': 'F3_3', 'dX': 29709.5, 'dY': 14107.6}
# {'strName': 'B5_1', 'dX': 13763.400000000001, 'dY': -22886.100000000002}
# {'strName': 'B5_2', 'dX': 12820.400000000001, 'dY': -23428.4}
# {'strName': 'B5_3', 'dX': 12503.5, 'dY': -24139.2}
# {'strName': 'C5_1', 'dX': 13517.5, 'dY': -13365.400000000001}
# {'strName': 'C5_2', 'dX': 12345.6, 'dY': -13724.400000000001}
# {'strName': 'C5_3', 'dX': 12180.5, 'dY': -14617.900000000001}
# {'strName': 'D5_1', 'dX': 13032.5, 'dY': -4327.6}
# {'strName': 'D5_2', 'dX': 13199.900000000001, 'dY': -5149.900000000001}
# {'strName': 'D5_3', 'dX': 13088.1, 'dY': -6125.0}
# {'strName': 'E5_1', 'dX': 12668.800000000001, 'dY': 5181.1}
# {'strName': 'E5_2', 'dX': 12408.7, 'dY': 5672.5}
# {'strName': 'E5_3', 'dX': 11988.400000000001, 'dY': 5957.400000000001}
# {'strName': 'F5_1', 'dX': 11929.1, 'dY': 14119.300000000001}
# {'strName': 'F5_2', 'dX': 11944.6, 'dY': 14779.1}
# {'strName': 'F5_3', 'dX': 12919.300000000001, 'dY': 15338.7}
# {'strName': 'B6_1', 'dX': 4779.7, 'dY': -22452.2}
# {'strName': 'B6_2', 'dX': 4090.5, 'dY': -22234.0}
# {'strName': 'B6_3', 'dX': 2637.3, 'dY': -21545.600000000002}
# {'strName': 'C6_1', 'dX': 3688.3, 'dY': -13200.400000000001}
# {'strName': 'C6_2', 'dX': 2850.2000000000003, 'dY': -13335.7}
# {'strName': 'C6_3', 'dX': 2020.9, 'dY': -14022.7}
# {'strName': 'D6_1', 'dX': 3741.6000000000004, 'dY': -4124.5}
# {'strName': 'D6_2', 'dX': 3120.3, 'dY': -3728.9}
# {'strName': 'D6_3', 'dX': 3773.6000000000004, 'dY': -2813.7000000000003}
# {'strName': 'E6_1', 'dX': 2993.6000000000004, 'dY': 5036.8}
# {'strName': 'E6_2', 'dX': 2399.8, 'dY': 4896.900000000001}
# {'strName': 'E6_3', 'dX': 2122.8, 'dY': 4113.400000000001}
# {'strName': 'F6_1', 'dX': 2662.0, 'dY': 14194.800000000001}
# {'strName': 'F6_2', 'dX': 3006.5, 'dY': 14718.900000000001}
# {'strName': 'F6_3', 'dX': 3980.1000000000004, 'dY': 15143.7}
# {'strName': 'B8_1', 'dX': -13754.900000000001, 'dY': -22301.100000000002}
# {'strName': 'B8_2', 'dX': -13600.400000000001, 'dY': -21453.300000000003}
# {'strName': 'B8_3', 'dX': -13944.400000000001, 'dY': -20608.4}
# {'strName': 'C8_1', 'dX': -13560.300000000001, 'dY': -13072.300000000001}
# {'strName': 'C8_2', 'dX': -12689.1, 'dY': -12526.2}
# {'strName': 'C8_3', 'dX': -11995.5, 'dY': -12314.800000000001}
# {'strName': 'D8_1', 'dX': -15485.400000000001, 'dY': -3244.9}
# {'strName': 'D8_2', 'dX': -13823.900000000001, 'dY': -2503.3}
# {'strName': 'D8_3', 'dX': -12223.5, 'dY': -3363.9}
# {'strName': 'E8_1', 'dX': -15560.5, 'dY': 5599.700000000001}
# {'strName': 'E8_2', 'dX': -14677.300000000001, 'dY': 6209.0}
# {'strName': 'E8_3', 'dX': -13958.800000000001, 'dY': 6320.8}
# {'strName': 'F8_1', 'dX': -14728.1, 'dY': 15214.400000000001}
# {'strName': 'F8_2', 'dX': -14010.5, 'dY': 15159.800000000001}
# {'strName': 'F8_3', 'dX': -12996.300000000001, 'dY': 14334.6}
# {'strName': 'B9_1', 'dX': -23238.5, 'dY': -22237.300000000003}
# {'strName': 'B9_2', 'dX': -23848.800000000003, 'dY': -22238.800000000003}
# {'strName': 'B9_3', 'dX': -24327.600000000002, 'dY': -21706.800000000003}
# {'strName': 'C9_1', 'dX': -24513.4, 'dY': -12552.0}
# {'strName': 'C9_2', 'dX': -24710.300000000003, 'dY': -13021.800000000001}
# {'strName': 'C9_3', 'dX': -24652.4, 'dY': -13598.2}
# {'strName': 'D9_1', 'dX': -24689.4, 'dY': -4106.5}
# {'strName': 'D9_2', 'dX': -24806.2, 'dY': -4685.8}
# {'strName': 'D9_3', 'dX': -24480.7, 'dY': -5482.0}
# {'strName': 'E9_1', 'dX': -24455.5, 'dY': 5136.700000000001}
# {'strName': 'E9_2', 'dX': -24353.9, 'dY': 4061.4}
# {'strName': 'E9_3', 'dX': -24506.5, 'dY': 3036.6000000000004}
# {'strName': 'F9_1', 'dX': -24757.600000000002, 'dY': 13841.5}
# {'strName': 'F9_2', 'dX': -24753.100000000002, 'dY': 13161.900000000001}
# {'strName': 'F9_3', 'dX': -23513.800000000003, 'dY': 12946.5}

# %% [markdown]
# Find matching positions between the image file and multipoints file

# %%
error_margin = 1e-3
matches = []

# Compare each plane from the first XML with each point from the second XML.
for plane in planes:
    for point in points:
        # Check if both X and Y differences are within the margin.
        if abs(plane['posX'] - point['dX']) <= error_margin and abs(plane['posY'] - point['dY']) <= error_margin:
            matches.append({
                'image_name': plane['image_name'],
                'point_name': point['strName'],
                'posX': plane['posX'],
                'posY': plane['posY'],
                'dX': point['dX'],
                'dY': point['dY']
            })

# %%
# Print the matching results
print("Matching positions (within margin of error):")
for match in matches:
    print(match)
# Out:
# Matching positions (within margin of error):
# {'image_name': '20250220_Galvano-Full-Plate (Series 0)', 'point_name': 'B2_1', 'posX': 42151.1, 'posY': -22766.5, 'dX': 42151.100000000006, 'dY': -22766.5}
# {'image_name': '20250220_Galvano-Full-Plate (Series 1)', 'point_name': 'B2_2', 'posX': 41225.0, 'posY': -22449.5, 'dX': 41225.0, 'dY': -22449.5}
# {'image_name': '20250220_Galvano-Full-Plate (Series 2)', 'point_name': 'B2_3', 'posX': 41365.7, 'posY': -21952.4, 'dX': 41365.700000000004, 'dY': -21952.4}
# {'image_name': '20250220_Galvano-Full-Plate (Series 3)', 'point_name': 'C2_1', 'posX': 40293.8, 'posY': -13686.6, 'dX': 40293.8, 'dY': -13686.6}
# {'image_name': '20250220_Galvano-Full-Plate (Series 4)', 'point_name': 'C2_2', 'posX': 40339.1, 'posY': -11346.8, 'dX': 40339.100000000006, 'dY': -11346.800000000001}
# {'image_name': '20250220_Galvano-Full-Plate (Series 5)', 'point_name': 'C2_3', 'posX': 39000.4, 'posY': -11719.0, 'dX': 39000.4, 'dY': -11719.0}
# {'image_name': '20250220_Galvano-Full-Plate (Series 6)', 'point_name': 'D2_1', 'posX': 41159.7, 'posY': -4477.3, 'dX': 41159.700000000004, 'dY': -4477.3}
# {'image_name': '20250220_Galvano-Full-Plate (Series 7)', 'point_name': 'D2_2', 'posX': 41577.1, 'posY': -2551.5, 'dX': 41577.100000000006, 'dY': -2551.5}
# {'image_name': '20250220_Galvano-Full-Plate (Series 8)', 'point_name': 'D2_3', 'posX': 38947.2, 'posY': -2794.1, 'dX': 38947.200000000004, 'dY': -2794.1000000000004}
# {'image_name': '20250220_Galvano-Full-Plate (Series 9)', 'point_name': 'E2_1', 'posX': 40389.6, 'posY': 4829.5, 'dX': 40389.600000000006, 'dY': 4829.5}
# {'image_name': '20250220_Galvano-Full-Plate (Series 10)', 'point_name': 'E2_2', 'posX': 41157.4, 'posY': 4672.5, 'dX': 41157.4, 'dY': 4672.5}
# {'image_name': '20250220_Galvano-Full-Plate (Series 11)', 'point_name': 'E2_3', 'posX': 42354.0, 'posY': 5574.1, 'dX': 42354.0, 'dY': 5574.1}
# {'image_name': '20250220_Galvano-Full-Plate (Series 12)', 'point_name': 'F2_1', 'posX': 39484.2, 'posY': 14312.0, 'dX': 39484.200000000004, 'dY': 14312.0}
# {'image_name': '20250220_Galvano-Full-Plate (Series 13)', 'point_name': 'F2_2', 'posX': 39096.7, 'posY': 15147.0, 'dX': 39096.700000000004, 'dY': 15147.0}
# {'image_name': '20250220_Galvano-Full-Plate (Series 14)', 'point_name': 'F2_3', 'posX': 40666.7, 'posY': 15376.3, 'dX': 40666.700000000004, 'dY': 15376.300000000001}
# {'image_name': '20250220_Galvano-Full-Plate (Series 15)', 'point_name': 'B3_1', 'posX': 32581.8, 'posY': -22678.7, 'dX': 32581.800000000003, 'dY': -22678.7}
# {'image_name': '20250220_Galvano-Full-Plate (Series 16)', 'point_name': 'B3_2', 'posX': 33403.2, 'posY': -22337.6, 'dX': 33403.200000000004, 'dY': -22337.600000000002}
# {'image_name': '20250220_Galvano-Full-Plate (Series 17)', 'point_name': 'B3_3', 'posX': 31548.5, 'posY': -20729.3, 'dX': 31548.5, 'dY': -20729.300000000003}
# {'image_name': '20250220_Galvano-Full-Plate (Series 18)', 'point_name': 'C3_1', 'posX': 32033.5, 'posY': -13499.9, 'dX': 32033.5, 'dY': -13499.900000000001}
# {'image_name': '20250220_Galvano-Full-Plate (Series 19)', 'point_name': 'C3_2', 'posX': 31556.1, 'posY': -11634.6, 'dX': 31556.100000000002, 'dY': -11634.6}
# {'image_name': '20250220_Galvano-Full-Plate (Series 20)', 'point_name': 'C3_3', 'posX': 30136.0, 'posY': -11804.9, 'dX': 30136.0, 'dY': -11804.900000000001}
# {'image_name': '20250220_Galvano-Full-Plate (Series 21)', 'point_name': 'D3_1', 'posX': 31347.0, 'posY': -5105.3, 'dX': 31347.0, 'dY': -5105.3}
# {'image_name': '20250220_Galvano-Full-Plate (Series 22)', 'point_name': 'D3_2', 'posX': 30362.1, 'posY': -4664.2, 'dX': 30362.100000000002, 'dY': -4664.2}
# {'image_name': '20250220_Galvano-Full-Plate (Series 23)', 'point_name': 'D3_3', 'posX': 29575.7, 'posY': -3901.6, 'dX': 29575.7, 'dY': -3901.6000000000004}
# {'image_name': '20250220_Galvano-Full-Plate (Series 24)', 'point_name': 'E3_1', 'posX': 30928.2, 'posY': 4715.1, 'dX': 30928.2, 'dY': 4715.1}
# {'image_name': '20250220_Galvano-Full-Plate (Series 25)', 'point_name': 'E3_2', 'posX': 30088.6, 'posY': 4821.7, 'dX': 30088.600000000002, 'dY': 4821.7}
# {'image_name': '20250220_Galvano-Full-Plate (Series 26)', 'point_name': 'E3_3', 'posX': 29123.0, 'posY': 4621.3, 'dX': 29123.0, 'dY': 4621.3}
# {'image_name': '20250220_Galvano-Full-Plate (Series 27)', 'point_name': 'F3_1', 'posX': 30464.0, 'posY': 13968.2, 'dX': 30464.0, 'dY': 13968.2}
# {'image_name': '20250220_Galvano-Full-Plate (Series 28)', 'point_name': 'F3_2', 'posX': 29709.5, 'posY': 14107.6, 'dX': 29709.5, 'dY': 14107.6}
# {'image_name': '20250220_Galvano-Full-Plate (Series 28)', 'point_name': 'F3_3', 'posX': 29709.5, 'posY': 14107.6, 'dX': 29709.5, 'dY': 14107.6}
# {'image_name': '20250220_Galvano-Full-Plate (Series 29)', 'point_name': 'F3_2', 'posX': 29709.5, 'posY': 14107.6, 'dX': 29709.5, 'dY': 14107.6}
# {'image_name': '20250220_Galvano-Full-Plate (Series 29)', 'point_name': 'F3_3', 'posX': 29709.5, 'posY': 14107.6, 'dX': 29709.5, 'dY': 14107.6}
# {'image_name': '20250220_Galvano-Full-Plate (Series 30)', 'point_name': 'B5_1', 'posX': 13763.4, 'posY': -22886.1, 'dX': 13763.400000000001, 'dY': -22886.100000000002}
# {'image_name': '20250220_Galvano-Full-Plate (Series 31)', 'point_name': 'B5_2', 'posX': 12820.4, 'posY': -23428.4, 'dX': 12820.400000000001, 'dY': -23428.4}
# {'image_name': '20250220_Galvano-Full-Plate (Series 32)', 'point_name': 'B5_3', 'posX': 12503.5, 'posY': -24139.2, 'dX': 12503.5, 'dY': -24139.2}
# {'image_name': '20250220_Galvano-Full-Plate (Series 33)', 'point_name': 'C5_1', 'posX': 13517.5, 'posY': -13365.4, 'dX': 13517.5, 'dY': -13365.400000000001}
# {'image_name': '20250220_Galvano-Full-Plate (Series 34)', 'point_name': 'C5_2', 'posX': 12345.6, 'posY': -13724.4, 'dX': 12345.6, 'dY': -13724.400000000001}
# {'image_name': '20250220_Galvano-Full-Plate (Series 35)', 'point_name': 'C5_3', 'posX': 12180.5, 'posY': -14617.9, 'dX': 12180.5, 'dY': -14617.900000000001}
# {'image_name': '20250220_Galvano-Full-Plate (Series 36)', 'point_name': 'D5_1', 'posX': 13032.5, 'posY': -4327.6, 'dX': 13032.5, 'dY': -4327.6}
# {'image_name': '20250220_Galvano-Full-Plate (Series 37)', 'point_name': 'D5_2', 'posX': 13199.9, 'posY': -5149.9, 'dX': 13199.900000000001, 'dY': -5149.900000000001}
# {'image_name': '20250220_Galvano-Full-Plate (Series 38)', 'point_name': 'D5_3', 'posX': 13088.1, 'posY': -6125.0, 'dX': 13088.1, 'dY': -6125.0}
# {'image_name': '20250220_Galvano-Full-Plate (Series 39)', 'point_name': 'E5_1', 'posX': 12668.8, 'posY': 5181.1, 'dX': 12668.800000000001, 'dY': 5181.1}
# {'image_name': '20250220_Galvano-Full-Plate (Series 40)', 'point_name': 'E5_2', 'posX': 12408.7, 'posY': 5672.5, 'dX': 12408.7, 'dY': 5672.5}
# {'image_name': '20250220_Galvano-Full-Plate (Series 41)', 'point_name': 'E5_3', 'posX': 11988.4, 'posY': 5957.4, 'dX': 11988.400000000001, 'dY': 5957.400000000001}
# {'image_name': '20250220_Galvano-Full-Plate (Series 42)', 'point_name': 'F5_1', 'posX': 11929.1, 'posY': 14119.3, 'dX': 11929.1, 'dY': 14119.300000000001}
# {'image_name': '20250220_Galvano-Full-Plate (Series 43)', 'point_name': 'F5_2', 'posX': 11944.6, 'posY': 14779.1, 'dX': 11944.6, 'dY': 14779.1}
# {'image_name': '20250220_Galvano-Full-Plate (Series 44)', 'point_name': 'F5_3', 'posX': 12919.3, 'posY': 15338.7, 'dX': 12919.300000000001, 'dY': 15338.7}
# {'image_name': '20250220_Galvano-Full-Plate (Series 45)', 'point_name': 'B6_1', 'posX': 4779.7, 'posY': -22452.2, 'dX': 4779.7, 'dY': -22452.2}
# {'image_name': '20250220_Galvano-Full-Plate (Series 46)', 'point_name': 'B6_2', 'posX': 4090.5, 'posY': -22234.0, 'dX': 4090.5, 'dY': -22234.0}
# {'image_name': '20250220_Galvano-Full-Plate (Series 47)', 'point_name': 'B6_3', 'posX': 2637.3, 'posY': -21545.6, 'dX': 2637.3, 'dY': -21545.600000000002}
# {'image_name': '20250220_Galvano-Full-Plate (Series 48)', 'point_name': 'C6_1', 'posX': 3688.3, 'posY': -13200.4, 'dX': 3688.3, 'dY': -13200.400000000001}
# {'image_name': '20250220_Galvano-Full-Plate (Series 49)', 'point_name': 'C6_2', 'posX': 2850.2, 'posY': -13335.7, 'dX': 2850.2000000000003, 'dY': -13335.7}
# {'image_name': '20250220_Galvano-Full-Plate (Series 50)', 'point_name': 'C6_3', 'posX': 2020.9, 'posY': -14022.7, 'dX': 2020.9, 'dY': -14022.7}
# {'image_name': '20250220_Galvano-Full-Plate (Series 51)', 'point_name': 'D6_1', 'posX': 3741.6, 'posY': -4124.5, 'dX': 3741.6000000000004, 'dY': -4124.5}
# {'image_name': '20250220_Galvano-Full-Plate (Series 52)', 'point_name': 'D6_2', 'posX': 3120.3, 'posY': -3728.9, 'dX': 3120.3, 'dY': -3728.9}
# {'image_name': '20250220_Galvano-Full-Plate (Series 53)', 'point_name': 'D6_3', 'posX': 3773.6, 'posY': -2813.7, 'dX': 3773.6000000000004, 'dY': -2813.7000000000003}
# {'image_name': '20250220_Galvano-Full-Plate (Series 54)', 'point_name': 'E6_1', 'posX': 2993.6, 'posY': 5036.8, 'dX': 2993.6000000000004, 'dY': 5036.8}
# {'image_name': '20250220_Galvano-Full-Plate (Series 55)', 'point_name': 'E6_2', 'posX': 2399.8, 'posY': 4896.9, 'dX': 2399.8, 'dY': 4896.900000000001}
# {'image_name': '20250220_Galvano-Full-Plate (Series 56)', 'point_name': 'E6_3', 'posX': 2122.8, 'posY': 4113.4, 'dX': 2122.8, 'dY': 4113.400000000001}
# {'image_name': '20250220_Galvano-Full-Plate (Series 57)', 'point_name': 'F6_1', 'posX': 2662.0, 'posY': 14194.8, 'dX': 2662.0, 'dY': 14194.800000000001}
# {'image_name': '20250220_Galvano-Full-Plate (Series 58)', 'point_name': 'F6_2', 'posX': 3006.5, 'posY': 14718.9, 'dX': 3006.5, 'dY': 14718.900000000001}
# {'image_name': '20250220_Galvano-Full-Plate (Series 59)', 'point_name': 'F6_3', 'posX': 3980.1, 'posY': 15143.7, 'dX': 3980.1000000000004, 'dY': 15143.7}
# {'image_name': '20250220_Galvano-Full-Plate (Series 60)', 'point_name': 'B8_1', 'posX': -13754.9, 'posY': -22301.1, 'dX': -13754.900000000001, 'dY': -22301.100000000002}
# {'image_name': '20250220_Galvano-Full-Plate (Series 61)', 'point_name': 'B8_2', 'posX': -13600.4, 'posY': -21453.3, 'dX': -13600.400000000001, 'dY': -21453.300000000003}
# {'image_name': '20250220_Galvano-Full-Plate (Series 62)', 'point_name': 'B8_3', 'posX': -13944.4, 'posY': -20608.4, 'dX': -13944.400000000001, 'dY': -20608.4}
# {'image_name': '20250220_Galvano-Full-Plate (Series 63)', 'point_name': 'C8_1', 'posX': -13560.3, 'posY': -13072.3, 'dX': -13560.300000000001, 'dY': -13072.300000000001}
# {'image_name': '20250220_Galvano-Full-Plate (Series 64)', 'point_name': 'C8_2', 'posX': -12689.1, 'posY': -12526.2, 'dX': -12689.1, 'dY': -12526.2}
# {'image_name': '20250220_Galvano-Full-Plate (Series 65)', 'point_name': 'C8_3', 'posX': -11995.5, 'posY': -12314.8, 'dX': -11995.5, 'dY': -12314.800000000001}
# {'image_name': '20250220_Galvano-Full-Plate (Series 66)', 'point_name': 'D8_1', 'posX': -15485.4, 'posY': -3244.9, 'dX': -15485.400000000001, 'dY': -3244.9}
# {'image_name': '20250220_Galvano-Full-Plate (Series 67)', 'point_name': 'D8_2', 'posX': -13823.9, 'posY': -2503.3, 'dX': -13823.900000000001, 'dY': -2503.3}
# {'image_name': '20250220_Galvano-Full-Plate (Series 68)', 'point_name': 'D8_3', 'posX': -12223.5, 'posY': -3363.9, 'dX': -12223.5, 'dY': -3363.9}
# {'image_name': '20250220_Galvano-Full-Plate (Series 69)', 'point_name': 'E8_1', 'posX': -15560.5, 'posY': 5599.7, 'dX': -15560.5, 'dY': 5599.700000000001}
# {'image_name': '20250220_Galvano-Full-Plate (Series 70)', 'point_name': 'E8_2', 'posX': -14677.3, 'posY': 6209.0, 'dX': -14677.300000000001, 'dY': 6209.0}
# {'image_name': '20250220_Galvano-Full-Plate (Series 71)', 'point_name': 'E8_3', 'posX': -13958.8, 'posY': 6320.8, 'dX': -13958.800000000001, 'dY': 6320.8}
# {'image_name': '20250220_Galvano-Full-Plate (Series 72)', 'point_name': 'F8_1', 'posX': -14728.1, 'posY': 15214.4, 'dX': -14728.1, 'dY': 15214.400000000001}
# {'image_name': '20250220_Galvano-Full-Plate (Series 73)', 'point_name': 'F8_2', 'posX': -14010.5, 'posY': 15159.8, 'dX': -14010.5, 'dY': 15159.800000000001}
# {'image_name': '20250220_Galvano-Full-Plate (Series 74)', 'point_name': 'F8_3', 'posX': -12996.3, 'posY': 14334.6, 'dX': -12996.300000000001, 'dY': 14334.6}
# {'image_name': '20250220_Galvano-Full-Plate (Series 75)', 'point_name': 'B9_1', 'posX': -23238.5, 'posY': -22237.3, 'dX': -23238.5, 'dY': -22237.300000000003}
# {'image_name': '20250220_Galvano-Full-Plate (Series 76)', 'point_name': 'B9_2', 'posX': -23848.8, 'posY': -22238.8, 'dX': -23848.800000000003, 'dY': -22238.800000000003}
# {'image_name': '20250220_Galvano-Full-Plate (Series 77)', 'point_name': 'B9_3', 'posX': -24327.6, 'posY': -21706.8, 'dX': -24327.600000000002, 'dY': -21706.800000000003}
# {'image_name': '20250220_Galvano-Full-Plate (Series 78)', 'point_name': 'C9_1', 'posX': -24513.4, 'posY': -12552.0, 'dX': -24513.4, 'dY': -12552.0}
# {'image_name': '20250220_Galvano-Full-Plate (Series 79)', 'point_name': 'C9_2', 'posX': -24710.3, 'posY': -13021.8, 'dX': -24710.300000000003, 'dY': -13021.800000000001}
# {'image_name': '20250220_Galvano-Full-Plate (Series 80)', 'point_name': 'C9_3', 'posX': -24652.4, 'posY': -13598.2, 'dX': -24652.4, 'dY': -13598.2}
# {'image_name': '20250220_Galvano-Full-Plate (Series 81)', 'point_name': 'D9_1', 'posX': -24689.4, 'posY': -4106.5, 'dX': -24689.4, 'dY': -4106.5}
# {'image_name': '20250220_Galvano-Full-Plate (Series 82)', 'point_name': 'D9_2', 'posX': -24806.2, 'posY': -4685.8, 'dX': -24806.2, 'dY': -4685.8}
# {'image_name': '20250220_Galvano-Full-Plate (Series 83)', 'point_name': 'D9_3', 'posX': -24480.7, 'posY': -5482.0, 'dX': -24480.7, 'dY': -5482.0}
# {'image_name': '20250220_Galvano-Full-Plate (Series 84)', 'point_name': 'E9_1', 'posX': -24455.5, 'posY': 5136.7, 'dX': -24455.5, 'dY': 5136.700000000001}
# {'image_name': '20250220_Galvano-Full-Plate (Series 85)', 'point_name': 'E9_2', 'posX': -24353.9, 'posY': 4061.4, 'dX': -24353.9, 'dY': 4061.4}
# {'image_name': '20250220_Galvano-Full-Plate (Series 86)', 'point_name': 'E9_3', 'posX': -24506.5, 'posY': 3036.6, 'dX': -24506.5, 'dY': 3036.6000000000004}
# {'image_name': '20250220_Galvano-Full-Plate (Series 87)', 'point_name': 'F9_1', 'posX': -24757.6, 'posY': 13841.5, 'dX': -24757.600000000002, 'dY': 13841.5}
# {'image_name': '20250220_Galvano-Full-Plate (Series 88)', 'point_name': 'F9_2', 'posX': -24753.1, 'posY': 13161.9, 'dX': -24753.100000000002, 'dY': 13161.900000000001}
# {'image_name': '20250220_Galvano-Full-Plate (Series 89)', 'point_name': 'F9_3', 'posX': -23513.8, 'posY': 12946.5, 'dX': -23513.800000000003, 'dY': 12946.5}
